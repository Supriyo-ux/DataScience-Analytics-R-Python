# %%
#numeric python ibrary
import numpy as np
x= np.array([[1,2,3],[4,5,6]])

# %%
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
x1= np.linspace(-10,10,100)
x1
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
y= np.sin(x)
import matplotlib.pyplot as plt
y
# Out:
# array([[ 0.84147098,  0.90929743,  0.14112001],
#        [-0.7568025 , -0.95892427, -0.2794155 ]])

# %%
plt.plot(x,y)

# %%
import numpy as np
x1= np.linspace(-10,10,100)
y= np.sin(x1)
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
#list
x=["hello", 3, "abc"]
type(x)
# Out:
# list

# %%
x2= "mohan"
type(x2)
# Out:
# str

# %%
x3=4
type(x3)
x4=2.09
type(x4)
# Out:
# float

# %%
x5=True
type(x5)
# Out:
# bool

# %%
vec1=[x2,x3,x4,x5]
vec1
# Out:
# ['mohan', 4, 2.09, True]

# %%
import sklearn

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()
type(iris_dataset)
iris_dataset

# %%
x=iris_dataset['data'] #separate the bunch of data type into Data and target ,that is  x and y variables
y= iris_dataset['target']
x

# %%
type(y)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(iris_dataset['data'],iris_dataset['target'])
xtrain,xtest,ytrain,ytest=train_test_split(x,y, random_state=0)

# %%
xtrain.shape
# Out:
# (112, 4)

# %%
x.shape
# Out:
# (150, 4)

# %%
xtest.shape
# Out:
# (38, 4)

# %%
ytrain
# Out:
# array([1, 1, 2, 0, 2, 0, 0, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2, 2, 1, 2,
#        1, 0, 2, 1, 1, 1, 1, 2, 0, 0, 2, 1, 0, 0, 1, 0, 2, 1, 0, 1, 2, 1,
#        0, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 0, 1, 2,
#        2, 0, 0, 0, 1, 1, 0, 0, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 0, 0, 2, 0,
#        2, 1, 1, 1, 2, 2, 1, 1, 0, 1, 2, 2, 0, 1, 1, 1, 1, 0, 0, 0, 2, 1,
#        2, 0])

# %%
#dataframe in python
import pandas  as pd
featurevecx=pd.DataFrame(xtrain, columns=iris_dataset.feature_names)
featurevecx
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.9               3.0                4.2               1.5
# 1                  5.8               2.6                4.0               1.2
# 2                  6.8               3.0                5.5               2.1
# 3                  4.7               3.2                1.3               0.2
# 4                  6.9               3.1                5.1               2.3
# ..                 ...               ...                ...               ...
# 107                4.9               3.1                1.5               0.1
# 108                6.3               2.9                5.6               1.8
# 109                5.8               2.7                4.1               1.0
# 110                7.7               3.8                6.7               2.2
# 111                4.6               3.2                1.4               0.2
#
# [112 rows x 4 columns]

# %%
import pandas as pd
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
pd.plotting.scatter_matrix(df, alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f716276e6a0>,
# ...
#       dtype=object)
